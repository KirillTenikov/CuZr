# %% [markdown]
# # Import

# %%
import gzip
import pickle
import numpy as np
import random
from pathlib import Path

# %% [markdown]
# # Dataset path

# %%
TRAIN_PATH = "../dataset/train.pckl.gz"
TEST_PATH  = "../dataset/test.pckl.gzip"

# %% [markdown]
# # Load data

# %%
with gzip.open(TRAIN_PATH, "rb") as f:
    train_df = pickle.load(f)

with gzip.open(TEST_PATH, "rb") as f:
    test_df = pickle.load(f)

print(len(train_df), len(test_df))
# Out:
# 24232 4242

# %% [markdown]
# # Build labeled ASE atoms list

# %%
def df_to_atoms(df):
    atoms_out = []
    
    for _, row in df.iterrows():
        a = row["ase_atoms"].copy()
        a.info["energy"] = float(row["energy_corrected"])
        a.arrays["forces"] = row["forces"]
        atoms_out.append(a)
        
    return atoms_out


train_atoms = df_to_atoms(train_df)
test_atoms  = df_to_atoms(test_df)

print(len(train_atoms), len(test_atoms))
# Out:
# 24232 4242

# %% [markdown]
# # Sanity checks

# %%
a = atoms_list[0]

print("Energy:", a.info["energy"])
print("Forces shape:", a.arrays["forces"].shape)
print("Natoms:", len(a))
# Out:
# Energy: -526.573784392
# Forces shape: (128, 3)
# Natoms: 128

# %% [markdown]
# # Filter broken entries (defensive)

# %%
clean_atoms = []

for a in atoms_list:
    if "energy" not in a.info:
        continue
    if "forces" not in a.arrays:
        continue
    if len(a.arrays["forces"]) != len(a):
        continue
    clean_atoms.append(a)

print("Clean structures:", len(clean_atoms))
# Out:
# Clean structures: 24232

# %% [markdown]
# # Export directly to extxyz

# %%
from ase.io import write

write("../dataset/train.extxyz", train_atoms)
write("../dataset/test.extxyz", test_atoms)

# %% [markdown]
# # Small debug subsets (still useful)

# %% [markdown]
# ## Shuffle

# %%
import random

random.seed(42)

train_shuffled = train_atoms.copy()
test_shuffled  = test_atoms.copy()

random.shuffle(train_shuffled)
random.shuffle(test_shuffled)

# %% [markdown]
# ## Write debug subsets

# %%
debug_train = train_shuffled[:200]
debug_test  = test_shuffled[:50]

write("../dataset/train_debug.extxyz", debug_train)
write("../dataset/test_debug.extxyz", debug_test )
