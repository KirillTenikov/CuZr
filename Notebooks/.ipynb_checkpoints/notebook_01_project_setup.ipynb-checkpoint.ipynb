# %%
from pyiron_atomistics import Project

# %%
pr = Project("cu_zr_mlip_project")
pr
# Out:
# {'groups': [], 'nodes': []}

# %%
pr.path
# Out:
# '/Users/ksenis/pyiron/projects/CuZr/cu_zr_mlip_project/'

# %%
s = pr.create.structure.bulk("Cu", cubic=True)
s
# Out:
# Cu: [0. 0. 0.]
# Cu: [0.    1.805 1.805]
# Cu: [1.805 0.    1.805]
# Cu: [1.805 1.805 0.   ]
# tags:
#     indices: [0 0 0 0]
# pbc: [ True  True  True]
# cell:
# Cell([3.61, 3.61, 3.61])
