# %% [markdown]
# # Imports

# %%
from pyiron_atomistics import Project
import pandas as pd

# %% [markdown]
# # Create pyiron project

# %%
pr = Project("../cu_zr_mlip_project")
structure = pr.create.structure.bulk("Cu", cubic=True)

# %% [markdown]
# # Create potential MACE

# %%
compiled_model="CuZr_mace_debug_compiled.model"
MACE_potential = pd.DataFrame({
    "Name": ["MACE_CuZr"],
    # these files will be copied into the job working directory
    "Filename": [[compiled_model]],
    "Model": ["Custom"],
    # IMPORTANT: order must match LAMMPS atom types in structure.inp
    "Species": [["Cu", "Zr"]],
    # These lines become potential.inp
    "Config": [[
        "pair_style mace\n",
        f"pair_coeff * * {compiled_model} Cu Zr\n",
    ]],
})

# %% [markdown]
# # Create LAMMPS job

# %%
job = pr.create.job.Lammps("mace_md_test", delete_existing_job=True)
job.structure = structure
job.potential = MACE_potential

# %% [markdown]
# # MD settings

# %%
job.calc_md(temperature=300, n_ionic_steps=1000)

# %% [markdown]
# # Run

# %%
job.run()
# Out:
# The job mace_md_test was saved and received the ID: 8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 job.run()
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_snippets/deprecate.py:155, in Deprecator.__deprecate_argument.<locals>.decorated(*args, **kwargs)
#     146     if kw in self.arguments:
#     147         warnings.warn(
#     148             message_format.format(
#     149                 f"{function.__module__}.{function.__qualname__}"
#    (...)    153             stacklevel=2,
#     154         )
# --> 155 return function(*args, **kwargs)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/generic.py:905, in GenericJob.run(self, delete_existing_job, repair, debug, run_mode, run_again)
#     903     self._run_if_repair()
#     904 elif status == "initialized":
# --> 905     self._run_if_new(debug=debug)
#     906 elif status == "created":
#     907     self._run_if_created()
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/generic.py:1463, in GenericJob._run_if_new(self, debug)
#    1455 def _run_if_new(self, debug: bool = False) -> None:
#    1456     """
#    1457     Internal helper function the run if new function is called when the job status is 'initialized'. It prepares
#    1458     the hdf5 file and the corresponding directory structure.
#    (...)   1461         debug (bool): Debug Mode
#    1462     """
# -> 1463     run_job_with_status_initialized(job=self, debug=debug)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/runfunction.py:208, in run_job_with_status_initialized(job, debug)
#     200 # The PythonFunctionContainerJob can generate the job_name during job.save(). In particular, this can lead to
#     201 # the job being reloaded from the database resulting in the job status to change from initialized to finished.
#     202 # Skipping the job.run() prevents raising a warning by calling job.run() on an already finished job.
#     203 if (
#     204     not job.status.finished
#     205     and not job.status.aborted
#     206     and not job.status.not_converged
#     207 ):
# --> 208     job.run()
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_snippets/deprecate.py:155, in Deprecator.__deprecate_argument.<locals>.decorated(*args, **kwargs)
#     146     if kw in self.arguments:
#     147         warnings.warn(
#     148             message_format.format(
#     149                 f"{function.__module__}.{function.__qualname__}"
#    (...)    153             stacklevel=2,
#     154         )
# --> 155 return function(*args, **kwargs)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/generic.py:907, in GenericJob.run(self, delete_existing_job, repair, debug, run_mode, run_again)
#     905     self._run_if_new(debug=debug)
#     906 elif status == "created":
# --> 907     self._run_if_created()
#     908 elif status == "submitted":
#     909     run_job_with_status_submitted(job=self)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/generic.py:1474, in GenericJob._run_if_created(self)
#    1465 def _run_if_created(self) -> Union[None, int]:
#    1466     """
#    1467     Internal helper function the run if created function is called when the job status is 'created'. It executes
#    1468     the simulation, either in modal mode, meaning waiting for the simulation to finish, manually, or submits the
#    (...)   1472         int: Queue ID - if the job was send to the queue
#    1473     """
# -> 1474     return run_job_with_status_created(job=self)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/runfunction.py:231, in run_job_with_status_created(job)
#     229     run_job_with_runmode_manually(job=job, _manually_print=True)
#     230 elif job.server.run_mode.modal:
# --> 231     job.run_static()
#     232 elif job.server.run_mode.srun:
#     233     run_job_with_runmode_srun(job=job)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/generic.py:943, in GenericJob.run_static(self)
#     941 self.status.running = True
#     942 if self._job_with_calculate_function:
# --> 943     execute_job_with_calculate_function(job=self)
#     944 else:
#     945     return execute_job_with_external_executable(job=self)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/runfunction.py:757, in run_time_decorator.<locals>.wrapper(job)
#     755 if not state.database.database_is_disabled and job.job_id is not None:
#     756     job.project.db.item_update({"timestart": datetime.now()}, job.job_id)
# --> 757     output = func(job)
#     758     job.project.db.item_update(job._runtime(), job.job_id)
#     759 else:
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/runfunction.py:1073, in execute_job_with_calculate_function(job)
#    1060 """
#    1061 The run_static() function is called internally in pyiron to trigger the execution of the executable. This is
#    1062 typically divided into three steps: (1) the generation of the calculate function and its inputs, (2) the
#    (...)   1066 in these three distinct steps is necessary to simplify the submission to an external executor.
#    1067 """
#    1068 try:
#    1069     (
#    1070         shell_output,
#    1071         parsed_output,
#    1072         job_crashed,
# -> 1073     ) = job.get_calculate_function()(**job.calculate_kwargs)
#    1074 except RuntimeError:
#    1075     raise_runtimeerror_for_failed_job(job=job)
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_base/jobs/job/generic.py:446, in GenericJob.calculate_kwargs(self)
#     427 """
#     428 Generate keyword arguments for the calculate() function. A new simulation code only has to extend the
#     429 get_input_parameter_dict() function which by default specifies an hierarchical dictionary with files_to_write
#    (...)    439     dict: keyword arguments for the calculate() function
#     440 """
#     441 executable, shell = self.executable.get_input_for_subprocess_call(
#     442     cores=self.server.cores, threads=self.server.threads, gpus=self.server.gpus
#     443 )
#     444 return {
#     445     "working_directory": self.working_directory,
# --> 446     "input_parameter_dict": self.get_input_parameter_dict(),
#     447     "executable_script": executable,
#     448     "shell_parameter": shell,
#     449     "cores": self.server.cores,
#     450     "threads": self.server.threads,
#     451     "gpus": self.server.gpus,
#     452     "conda_environment_name": self.server.conda_environment_name,
#     453     "conda_environment_path": self.server.conda_environment_path,
#     454     "accept_crash": self.server.accept_crash,
#     455     "accepted_return_codes": self.executable.accepted_return_codes,
#     456     "output_parameter_dict": self.get_output_parameter_dict(),
#     457 }
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_atomistics/lammps/base.py:393, in LammpsBase.get_input_parameter_dict(self)
#     391 if update_input_hdf5:
#     392     self.input.to_hdf(self._hdf5)
# --> 393 if self.input.potential.files is not None:
#     394     input_file_dict["files_to_copy"].update(
#     395         {os.path.basename(f): f for f in self.input.potential.files}
#     396     )
#     397 input_file_dict["files_to_create"].update(
#     398     {
#     399         "structure.inp": lmp_structure._string_input,
#    (...)    402     }
#     403 )
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_atomistics/lammps/potential.py:81, in LammpsPotential.files(self)
#      74 relative_file_paths = [
#      75     files
#      76     for files in list(self._df["Filename"])[0]
#      77     if not os.path.isabs(files)
#      78 ]
#      79 for path in relative_file_paths:
#      80     absolute_file_paths.append(
# ---> 81         LammpsPotentialFile.find_potential_file(path)
#      82     )
#      83 return absolute_file_paths
#
# File /opt/miniconda3/envs/pyiron_clean/lib/python3.11/site-packages/pyiron_atomistics/atomistics/job/potentials.py:191, in PotentialAbstract.find_potential_file(cls, path)
#     189     return res.first(path)
#     190 except ResourceNotFound:
# --> 191     raise ValueError(f"Could not find file '{path}' in {res}!") from None
#
# ValueError: Could not find file 'CuZr_mace_debug_compiled.model' in ResolverChain(ResourceResolver(['/Users/ksenis/pyiron/pyiron-resources', '/opt/miniconda3/envs/pyiron_clean/share/pyiron'], 'lammps', 'potentials'), ResourceResolver(['/opt/miniconda3/envs/pyiron_clean'], 'share', 'iprpy'))!

# %% [markdown]
# # MD integrator

# %%
dyn = Langevin(
    atoms,
    timestep=1.0 * units.fs,
    temperature_K=300,
    friction=0.01
)

# %% [markdown]
# # Attach trajectory writer

# %%
traj_file = "mace_md.traj"

def write_frame():
    write(traj_file, atoms, append=True)

dyn.attach(write_frame, interval=10)

# %% [markdown]
# # Run MD

# %%
dyn.run(2000)   # steps
